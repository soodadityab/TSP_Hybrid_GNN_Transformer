# %%
# !pip install gymnasium
# !pip install torchrl
# !pip install TensorDict
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torchrl in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from torchrl) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchrl) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchrl) (24.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from torchrl) (2.2.1)
# Requirement already satisfied: tensordict>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from torchrl) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchrl) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.3.0->torchrl) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.3.0->torchrl) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.3.0->torchrl) (1.3.0)
# Requirement already satisfied: TensorDict in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from TensorDict) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from TensorDict) (1.25.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from TensorDict) (2.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->TensorDict) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.3.0->TensorDict) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.3.0->TensorDict) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.3.0->TensorDict) (1.3.0)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchrl.modules import DecisionTransformer
from torchrl.objectives import DTLoss
import gymnasium as gym
from gymnasium import spaces
from tensordict import TensorDict
from torch.nn import CrossEntropyLoss
import torch.nn.functional as F

# %% [markdown]
# Env

# %%
class ATSPEnv(gym.Env):
    def __init__(self, num_nodes, seed=None):
        super(ATSPEnv, self).__init__()
        self.num_nodes = num_nodes
        self.seed = seed
        self.action_space = spaces.Discrete(self.num_nodes)
        self.observation_space = spaces.Dict({
            "adjacency_matrix": spaces.Box(low=0, high=np.inf, shape=(self.num_nodes, self.num_nodes), dtype=np.float32),
            "current_node": spaces.Discrete(self.num_nodes),
            "visited": spaces.MultiBinary(self.num_nodes)
        })
        self.graph = self._generate_random_graph()
        self.reset()

    def _generate_random_graph(self):
        # if self.seed is not None:
        #     np.random.seed(self.seed)

        locations = np.random.rand(self.num_nodes, 2)
        graph = np.zeros((self.num_nodes, self.num_nodes))
        for i in range(self.num_nodes):
            for j in range(i + 1, self.num_nodes):
                distance = np.linalg.norm(locations[i] - locations[j])
                graph[i, j] = distance
                graph[j, i] = distance

        # np.fill_diagonal(graph, np.inf)
        np.fill_diagonal(graph, 1000)
        return graph

    def reset(self):
        self.graph = self._generate_random_graph()
        self.current_node = np.random.choice(self.num_nodes)
        self.visited = np.zeros(self.num_nodes, dtype=bool)
        # self.visited[self.current_node] = True
        self.path = self.optimal_solution()
        print(self.path)
        return self._get_obs(), {}

    def _get_obs(self):
        obs = {
            "adjacency_matrix": self.graph,
            "current_node": self.current_node,
            "visited": self.visited
        }
        return obs

    def step(self, action):
        done = False
        if self.visited[action]:
            reward = -20.0
            # done = True
        else:
            reward = -self._compute_distance(self.current_node, action)
            self.current_node = action
            self.visited[action] = True
            done = self.visited.all()

        reward = np.clip(reward, -20.0, 10.0)
        return self._get_obs(), reward, done, {}

    def _compute_distance(self, node1, node2):
        return self.graph[node1, node2]

    def render(self, mode='human'):
        print(f'Visited: {np.where(self.visited)[0]}')

    def optimal_solution(self):
        current_node = 0
        visited = np.zeros(self.num_nodes, dtype=bool)
        path = [current_node]
        visited[current_node] = True

        # Loop until all nodes are visited
        while not visited.all():
            # Find the nearest unvisited neighbor
            next_node = None
            min_distance = np.inf
            for i in range(self.num_nodes):
                if not visited[i] and self.graph[current_node, i] < min_distance:
                    min_distance = self.graph[current_node, i]
                    next_node = i

            # Move to the next node
            current_node = next_node
            visited[current_node] = True
            path.append(current_node)

        # Close the tour by returning to the starting node
        # path.append(path[0])

        # one hot encoding--idk if needed
        path_tensor = torch.zeros((self.num_nodes, self.num_nodes))
        for i in range(self.num_nodes):
          curr = path[i]
          path_tensor[i][curr] = 1
        return path
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Train

# %%
# make it so that it AR predcits the full path one step at a time
# this path is then compared to optimal path
# error is MSE between the two
def compute_tour_length(adj_matrix, tour):
    tour_length = 0
    for i in range(len(tour) - 1):
        tour_length += adj_matrix[tour[i], tour[i + 1]]
    tour_length += adj_matrix[tour[-1], tour[0]]  # Return to the starting point
    return tour_length

def train_online(model, env, num_episodes=100):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    # criterion = DTLoss(actor_network=model, loss_function="cross_entropy")
    criterion = CrossEntropyLoss()

    for episode in range(num_episodes):
        state, _ = env.reset()
        done = False
        total_loss = 0
        total_reward = 0
        counter = 0
        episode_rewards = []

        while not done:
            curr_node = state["current_node"]
            visited = state["visited"]
            adj_matrix = state["adjacency_matrix"]
            num_nodes = adj_matrix.shape[0]

            # obs for each node
            node_observations = []
            for i in range(num_nodes):
                distance_to_current_node = adj_matrix[curr_node, i]
                visited_status = float(visited[i])
                node_observations.append([distance_to_current_node, visited_status])
            node_observations = torch.tensor(node_observations).float().unsqueeze(0)  # [1, num_nodes, 2]

            # action for each node
            actions = []
            for i in range(num_nodes):
                next_node_index = i
                travel_cost = adj_matrix[curr_node, next_node_index]
                actions.append([next_node_index, travel_cost])
            actions = torch.tensor(actions).float().unsqueeze(0) # [1, num_nodes, 2]

            # return_to_go = torch.tensor(np.random.rand(1, num_nodes, 1), dtype=torch.float)

            # action probabilities
            action_probs = model(node_observations, actions, return_to_go)  # [1, num_nodes, 128]
            action_probs_no_batch = action_probs.squeeze(0) # [num_nodes, 128]
            score_layer = nn.Linear(128, 1)

            # convert features to scores
            scores = score_layer(action_probs_no_batch)
            probabilities = F.softmax(scores.squeeze(1), dim=-1)

            mask = torch.tensor(visited, dtype=torch.bool)
            print(mask)
            masked_probabilities = probabilities.clone()
            masked_probabilities[mask] = 0
            distribution = torch.distributions.Categorical(probs=masked_probabilities)

            # Sample an action
            selected_action = distribution.sample().item()
            print(masked_probabilities)
            print(selected_action)

            optimal_path = env.path
            optimal_action = optimal_path[counter]
            optimal_action = torch.tensor([optimal_action])

            # Need to get scores in shape batches, classes
            scores = scores.transpose(0, 1)

            loss = criterion(scores, optimal_action.long())

            total_loss += loss.item()

            # backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # next state
            next_state, reward, done, _ = env.step(selected_action)
            total_reward += reward
            episode_rewards.append(reward)
            state = next_state
            counter += 1
        print("finished!")
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}, Episode Loss: {total_loss}")

if __name__ == "__main__":
    env = ATSPEnv(num_nodes=5, seed=42)

    state_dim = 2
    action_dim = 2

    config = DecisionTransformer.DTConfig(n_embd=128)
    model = DecisionTransformer(state_dim=state_dim, action_dim=action_dim, config=config)

    train_online(model, env)
    torch.save(model.state_dict(), "decision_transformer_model.pth")
# Out:
# [0, 1, 4, 2, 3]
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.2129, 0.2089, 0.1776, 0.1897, 0.2109], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.1597, 0.1352, 0.1432, 0.1862, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False,  True])
# tensor([0.1467, 0.0000, 0.2510, 0.1968, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False,  True])
# tensor([0.2232, 0.0000, 0.0000, 0.2053, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True,  True])
# tensor([0.1908, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.1961, 0.1900, 0.2467, 0.1718, 0.1954], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1336, 0.0000, 0.1776, 0.1426, 0.2322], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.1863, 0.0000, 0.1828, 0.1821, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.1487, 0.2021, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1351, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 1, 4, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.2025, 0.1376, 0.2826, 0.1998, 0.1775], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2114, 0.2205, 0.0000, 0.2259, 0.1834], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True, False,  True])
# tensor([0.1018, 0.1099, 0.0000, 0.1578, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False,  True,  True,  True])
# tensor([0.1764, 0.2259, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True,  True,  True])
# tensor([0.2151, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 4, 3, 2, 1]
# tensor([False, False, False, False, False])
# tensor([0.1852, 0.1922, 0.1448, 0.1633, 0.3147], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2444, 0.0000, 0.1324, 0.1692, 0.1490], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False, False])
# tensor([0.2438, 0.0000, 0.0000, 0.1846, 0.1799], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True, False])
# tensor([0.1905, 0.0000, 0.0000, 0.0000, 0.2215], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.1853], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.1823, 0.1855, 0.1578, 0.1850, 0.2894], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1704, 0.1819, 0.1959, 0.0000, 0.1965], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True, False])
# tensor([0.2365, 0.2062, 0.0000, 0.0000, 0.1502], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True, False])
# tensor([0.0000, 0.1896, 0.0000, 0.0000, 0.2017], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1605, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.2149, 0.2071, 0.2387, 0.1632, 0.1761], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.2088, 0.1835, 0.1971, 0.0000, 0.2035], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True, False])
# tensor([0.1828, 0.0000, 0.2383, 0.0000, 0.2061], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True, False])
# tensor([0.2153, 0.0000, 0.0000, 0.0000, 0.3273], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True,  True,  True,  True])
# tensor([0.2264, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 1, 3, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.2140, 0.1234, 0.1959, 0.2621, 0.2045], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1865, 0.2681, 0.1934, 0.0000, 0.1682], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True, False])
# tensor([0.1787, 0.1740, 0.0000, 0.0000, 0.2161], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True, False])
# tensor([0.0000, 0.2921, 0.0000, 0.0000, 0.2088], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2322], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.1596, 0.1739, 0.2844, 0.1684, 0.2138], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.2332, 0.2131, 0.1894, 0.1515, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False,  True])
# tensor([0.1999, 0.0000, 0.2546, 0.2172, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True,  True])
# tensor([0.2121, 0.0000, 0.2013, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2527, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 1, 3, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.1989, 0.1704, 0.2268, 0.1981, 0.2058], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2737, 0.0000, 0.2024, 0.2220, 0.1474], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.1871, 0.0000, 0.2074, 0.1656, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False,  True])
# tensor([0.1939, 0.0000, 0.0000, 0.1967, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.2282, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 2, 3, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.2433, 0.2244, 0.2170, 0.1363, 0.1791], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1575, 0.1893, 0.0000, 0.1743, 0.2438], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False, False])
# tensor([0.2119, 0.0000, 0.0000, 0.2314, 0.2049], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True,  True, False,  True])
# tensor([0.2021, 0.0000, 0.0000, 0.2202, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True,  True])
# tensor([0.1877, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.2024, 0.2044, 0.2409, 0.1554, 0.1970], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1808, 0.1613, 0.1975, 0.1976], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.2699, 0.1683, 0.1914], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.1749, 0.1956], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1462, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 2, 4, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.1708, 0.1999, 0.2029, 0.1713, 0.2552], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2530, 0.1753, 0.0000, 0.1857, 0.2182], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True, False,  True])
# tensor([0.1429, 0.1852, 0.0000, 0.1135, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False,  True])
# tensor([0.2131, 0.0000, 0.0000, 0.2485, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True,  True])
# tensor([0.1909, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 2, 1, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2237, 0.1922, 0.2322, 0.1917, 0.1603], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1715, 0.0000, 0.2145, 0.2303, 0.1572], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True, False])
# tensor([0.1886, 0.0000, 0.1810, 0.0000, 0.1740], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True, False])
# tensor([0.2648, 0.0000, 0.0000, 0.0000, 0.1671], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.1740], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 1, 2, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2439, 0.1362, 0.2195, 0.1964, 0.2041], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1348, 0.1519, 0.2078, 0.1750], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.1816, 0.0000, 0.1849, 0.2161], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2308, 0.1790], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2226], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.2160, 0.1798, 0.1982, 0.1828, 0.2233], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1708, 0.2307, 0.1603, 0.1696], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.1889, 0.2176, 0.0000, 0.1874], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False, False,  True,  True])
# tensor([0.0000, 0.2222, 0.1892, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1882, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 1, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.1664, 0.2164, 0.2114, 0.2169, 0.1889], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1841, 0.0000, 0.2340, 0.2293, 0.2035], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False, False])
# tensor([0.2064, 0.0000, 0.0000, 0.1992, 0.1990], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2506, 0.2580], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2106], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 2, 4, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.2327, 0.2120, 0.2026, 0.1537, 0.1991], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2332, 0.0000, 0.1807, 0.2091, 0.1973], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.2268, 0.0000, 0.1521, 0.2082, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False,  True])
# tensor([0.2252, 0.0000, 0.0000, 0.1990, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1665, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.1914, 0.2189, 0.2021, 0.1546, 0.2331], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1963, 0.0000, 0.1430, 0.2267, 0.1982], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True, False])
# tensor([0.1824, 0.0000, 0.2068, 0.0000, 0.1805], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False,  True,  True])
# tensor([0.1679, 0.0000, 0.1963, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1386, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 2, 4, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.1706, 0.1938, 0.2519, 0.2051, 0.1785], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1624, 0.2240, 0.1859, 0.0000, 0.1535], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.2507, 0.1836, 0.1540, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True,  True])
# tensor([0.2044, 0.0000, 0.1813, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True,  True])
# tensor([0.2447, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 1, 2, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.1667, 0.2471, 0.2573, 0.1864, 0.1426], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1365, 0.2241, 0.1919, 0.0000, 0.2357], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True, False])
# tensor([0.2252, 0.0000, 0.2022, 0.0000, 0.1977], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False,  True,  True])
# tensor([0.2059, 0.0000, 0.1602, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2283, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 4, 3, 2, 1]
# tensor([False, False, False, False, False])
# tensor([0.2039, 0.1915, 0.2625, 0.1750, 0.1671], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1976, 0.1910, 0.1958, 0.2603], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.2150, 0.1493, 0.0000, 0.2011], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False, False,  True,  True])
# tensor([0.0000, 0.2044, 0.1902, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2128, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 3, 4, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.2085, 0.1835, 0.2012, 0.1828, 0.2241], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2198, 0.2133, 0.0000, 0.2034, 0.1654], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False, False])
# tensor([0.2321, 0.0000, 0.0000, 0.1960, 0.2150], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True,  True, False,  True])
# tensor([0.1722, 0.0000, 0.0000, 0.1487, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True,  True])
# tensor([0.1841, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 2, 4, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.2757, 0.1520, 0.2013, 0.1735, 0.1975], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2423, 0.1783, 0.2117, 0.2097], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.1772, 0.1459, 0.1803], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.1515, 0.1673], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2093], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 2, 3, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.1927, 0.1616, 0.1739, 0.2828, 0.1890], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1998, 0.2075, 0.2174, 0.0000, 0.2308], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.1876, 0.2800, 0.1459, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True,  True])
# tensor([0.1668, 0.2110, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1925, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 2, 4, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.1669, 0.2227, 0.2368, 0.1800, 0.1936], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.2266, 0.2409, 0.2291, 0.2218, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True,  True])
# tensor([0.1435, 0.2370, 0.1559, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True,  True])
# tensor([0.2039, 0.2338, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True,  True,  True])
# tensor([0.1700, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 4, 2, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.2179, 0.2763, 0.1498, 0.1255, 0.2305], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.2150, 0.2186, 0.2341, 0.1897, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.2055, 0.2666, 0.2168, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.2648, 0.2056, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1938, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.1895, 0.1977, 0.1710, 0.2365, 0.2054], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1953, 0.1919, 0.1337, 0.2098], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.1930, 0.2145, 0.0000, 0.1779], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True,  True, False])
# tensor([0.0000, 0.2232, 0.0000, 0.0000, 0.2040], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.3044], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 1, 3, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.2240, 0.1889, 0.1967, 0.2180, 0.1724], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2009, 0.1914, 0.2584, 0.2318], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.1722, 0.1898, 0.1813, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True, False,  True])
# tensor([0.0000, 0.1748, 0.0000, 0.1869, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1503, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 2, 4, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.2632, 0.2281, 0.2033, 0.1316, 0.1737], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1398, 0.0000, 0.1836, 0.1654, 0.1826], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True, False])
# tensor([0.2094, 0.0000, 0.1786, 0.0000, 0.2030], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False,  True,  True])
# tensor([0.2439, 0.0000, 0.1994, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True,  True])
# tensor([0.1051, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 4, 1, 2, 3]
# tensor([False, False, False, False, False])
# tensor([0.1900, 0.2270, 0.1662, 0.1626, 0.2543], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1642, 0.2275, 0.0000, 0.1937, 0.1991], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False, False])
# tensor([0.2129, 0.0000, 0.0000, 0.1807, 0.1755], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.1529, 0.2012], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1792, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.2306, 0.2848, 0.0988, 0.2058, 0.1800], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2144, 0.0000, 0.1956, 0.2153, 0.2068], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False, False])
# tensor([0.1304, 0.0000, 0.0000, 0.1559, 0.1549], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True,  True, False,  True])
# tensor([0.2390, 0.0000, 0.0000, 0.2057, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1413, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 2, 1, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2064, 0.1822, 0.2139, 0.2164, 0.1811], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2396, 0.1989, 0.0000, 0.1636, 0.1810], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False,  True,  True, False])
# tensor([0.1980, 0.2152, 0.0000, 0.0000, 0.2124], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True, False])
# tensor([0.0000, 0.2326, 0.0000, 0.0000, 0.1502], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.1450], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.2858, 0.1752, 0.1639, 0.1738, 0.2013], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1456, 0.1922, 0.0000, 0.2838, 0.1942], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False,  True,  True, False])
# tensor([0.1771, 0.2171, 0.0000, 0.0000, 0.1814], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True,  True,  True])
# tensor([0.2110, 0.1503, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2263, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 2, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.2786, 0.1940, 0.1817, 0.2132, 0.1325], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.2224, 0.2162, 0.2535, 0.0000, 0.1802], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.2637, 0.1831, 0.1986, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True,  True])
# tensor([0.1984, 0.0000, 0.2879, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1568, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 3, 1, 4, 2]
# tensor([False, False, False, False, False])
# tensor([0.1818, 0.2004, 0.2158, 0.1965, 0.2055], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2074, 0.0000, 0.1994, 0.1428, 0.1974], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True, False])
# tensor([0.2879, 0.0000, 0.1484, 0.0000, 0.2056], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.1560, 0.0000, 0.1920], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1788, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 3, 2, 4, 1]
# tensor([False, False, False, False, False])
# tensor([0.2373, 0.2122, 0.1807, 0.2149, 0.1549], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1872, 0.0000, 0.2452, 0.1942, 0.1699], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False, False])
# tensor([0.1691, 0.0000, 0.0000, 0.1740, 0.2081], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.1984, 0.2024], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2214], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 4, 1, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.2303, 0.1893, 0.2408, 0.2016, 0.1379], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2281, 0.2081, 0.0000, 0.2127, 0.1694], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False, False])
# tensor([0.1564, 0.0000, 0.0000, 0.1841, 0.2415], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True, False])
# tensor([0.2080, 0.0000, 0.0000, 0.0000, 0.2023], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.1821], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.1674, 0.1692, 0.2355, 0.1884, 0.2396], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1943, 0.0000, 0.1978, 0.2158, 0.2357], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.1756, 0.1766, 0.1479], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.1816, 0.2112, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.2268, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 1, 2, 3, 4]
# tensor([False, False, False, False, False])
# tensor([0.2277, 0.1846, 0.1673, 0.2304, 0.1900], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1981, 0.1680, 0.2123, 0.0000, 0.2131], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True, False])
# tensor([0.1984, 0.0000, 0.1674, 0.0000, 0.1807], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True, False])
# tensor([0.1778, 0.0000, 0.0000, 0.0000, 0.1628], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.1749], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 1, 2, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2042, 0.2157, 0.1904, 0.2295, 0.1602], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2181, 0.2145, 0.0000, 0.2312, 0.1629], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False, False])
# tensor([0.2045, 0.0000, 0.0000, 0.1900, 0.1914], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True,  True, False,  True])
# tensor([0.2243, 0.0000, 0.0000, 0.2136, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True,  True])
# tensor([0.1673, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 2, 1, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2189, 0.1818, 0.2278, 0.2001, 0.1713], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.2084, 0.1992, 0.2048, 0.2059, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.1906, 0.1879, 0.1974, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True,  True])
# tensor([0.0000, 0.1793, 0.2358, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2184, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.1751, 0.1890, 0.2069, 0.2245, 0.2045], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1932, 0.2267, 0.2045, 0.0000, 0.1609], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.2267, 0.1816, 0.2076, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False,  True,  True])
# tensor([0.0000, 0.1979, 0.1506, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2174, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 1, 4, 2, 3]
# tensor([False, False, False, False, False])
# tensor([0.1667, 0.2130, 0.2170, 0.2082, 0.1951], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.1925, 0.2146, 0.2055, 0.2031, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False,  True])
# tensor([0.2279, 0.2224, 0.0000, 0.2320, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True, False,  True])
# tensor([0.0000, 0.2018, 0.0000, 0.1610, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2223, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.1940, 0.1888, 0.2035, 0.2068, 0.2069], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.2180, 0.1768, 0.1868, 0.0000, 0.1966], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True, False])
# tensor([0.2735, 0.2037, 0.0000, 0.0000, 0.1863], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True,  True,  True])
# tensor([0.2222, 0.2015, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1987, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 1, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.2208, 0.2046, 0.1971, 0.1984, 0.1792], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2140, 0.1794, 0.0000, 0.1681, 0.1684], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.2135, 0.0000, 0.1995, 0.1788], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False,  True,  True, False])
# tensor([0.0000, 0.2383, 0.0000, 0.0000, 0.1705], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2147, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 2, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.2192, 0.1752, 0.2341, 0.1851, 0.1864], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1834, 0.1964, 0.1934, 0.2039], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.2470, 0.0000, 0.1660, 0.1821], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2151, 0.2012], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.2424, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 3, 4, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.1634, 0.1902, 0.2580, 0.1814, 0.2071], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2333, 0.1672, 0.1763, 0.1938], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.1614, 0.1653, 0.0000, 0.1578], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False, False,  True,  True])
# tensor([0.0000, 0.2338, 0.1814, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2282, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 1, 2, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2361, 0.2093, 0.1990, 0.1263, 0.2294], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1797, 0.0000, 0.1851, 0.1971, 0.2154], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True, False])
# tensor([0.2110, 0.0000, 0.2322, 0.0000, 0.2149], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False,  True,  True])
# tensor([0.2062, 0.0000, 0.1758, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1842, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 2, 1, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.1541, 0.2282, 0.2448, 0.1683, 0.2046], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1768, 0.2028, 0.2325, 0.1932], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.1754, 0.0000, 0.1859, 0.1855], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2162, 0.1674], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2105], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.1709, 0.2059, 0.1983, 0.2532, 0.1716], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1944, 0.0000, 0.2287, 0.2165, 0.1670], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.2380, 0.0000, 0.2291, 0.1919, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.2425, 0.1682, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.2054, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 2, 1, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.1996, 0.1792, 0.2203, 0.2210, 0.1799], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2185, 0.1994, 0.0000, 0.1890, 0.2307], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True, False,  True])
# tensor([0.2053, 0.2054, 0.0000, 0.2005, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False,  True,  True,  True])
# tensor([0.1969, 0.1884, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2280, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.2563, 0.1444, 0.2064, 0.1997, 0.1932], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.1922, 0.1781, 0.2305, 0.1981, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.1683, 0.2134, 0.1948, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.1751, 0.1480, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2284, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 4, 2, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.1751, 0.2108, 0.2539, 0.1454, 0.2149], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1748, 0.2021, 0.0000, 0.2008, 0.1899], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False, False])
# tensor([0.1956, 0.0000, 0.0000, 0.2194, 0.2089], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2312, 0.1926], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2282], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 3, 2, 4, 1]
# tensor([False, False, False, False, False])
# tensor([0.1805, 0.2160, 0.2048, 0.1783, 0.2203], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2184, 0.0000, 0.1706, 0.2299, 0.1887], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.1871, 0.0000, 0.2314, 0.1879, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True,  True])
# tensor([0.2383, 0.0000, 0.1796, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1655, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 2, 4, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.2065, 0.1932, 0.2217, 0.1673, 0.2113], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1656, 0.2121, 0.0000, 0.2339, 0.1917], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True, False,  True])
# tensor([0.1841, 0.1777, 0.0000, 0.2457, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False,  True])
# tensor([0.1967, 0.0000, 0.0000, 0.1893, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.2567, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 2, 1, 3, 4]
# tensor([False, False, False, False, False])
# tensor([0.2302, 0.2357, 0.1866, 0.1697, 0.1778], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2133, 0.1896, 0.1538, 0.1741], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.1702, 0.2229, 0.2113], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.1927, 0.2230, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2086, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 2, 4, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.1930, 0.1831, 0.2017, 0.1978, 0.2243], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2403, 0.0000, 0.1499, 0.1801, 0.2380], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False, False])
# tensor([0.2238, 0.0000, 0.0000, 0.2220, 0.2028], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2142, 0.1838], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2479], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 1, 2, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.1858, 0.1556, 0.2378, 0.2377, 0.1830], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2333, 0.0000, 0.1561, 0.1920, 0.2580], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False, False])
# tensor([0.2063, 0.0000, 0.0000, 0.2022, 0.1946], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True, False])
# tensor([0.2539, 0.0000, 0.0000, 0.0000, 0.1706], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2032], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 2, 4, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.1926, 0.2360, 0.2277, 0.1611, 0.1825], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1749, 0.2151, 0.2149, 0.1711], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.2199, 0.1785, 0.1877, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.2010, 0.1966, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1801, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.1924, 0.2190, 0.1618, 0.2463, 0.1805], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2311, 0.0000, 0.1709, 0.2704, 0.1440], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True, False])
# tensor([0.2057, 0.0000, 0.1547, 0.0000, 0.2046], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.2033, 0.0000, 0.1822], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2123, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 4, 1, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.2026, 0.1854, 0.2060, 0.2162, 0.1898], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.2106, 0.2164, 0.1902, 0.1845, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False,  True])
# tensor([0.2054, 0.1694, 0.0000, 0.2483, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True, False,  True])
# tensor([0.0000, 0.1517, 0.0000, 0.1982, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1702, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 4, 1, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.2400, 0.1835, 0.1871, 0.1866, 0.2028], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1821, 0.0000, 0.2240, 0.2046, 0.2031], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.2352, 0.1938, 0.1978], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2076, 0.2121], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1960, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 4, 1, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.2317, 0.1632, 0.1942, 0.2097, 0.2011], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1754, 0.2584, 0.2097, 0.0000, 0.1961], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.1889, 0.2083, 0.1960, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True,  True])
# tensor([0.1991, 0.2152, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2175, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 2, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.1985, 0.2296, 0.2111, 0.1950, 0.1659], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1662, 0.0000, 0.2028, 0.2234, 0.2045], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.2057, 0.0000, 0.2006, 0.2139, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.2044, 0.2201, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1830, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 3, 1, 4, 2]
# tensor([False, False, False, False, False])
# tensor([0.2185, 0.1786, 0.2666, 0.1627, 0.1735], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1550, 0.0000, 0.2017, 0.1612, 0.2173], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.1868, 0.0000, 0.1917, 0.2697, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True,  True])
# tensor([0.2099, 0.0000, 0.1895, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True,  True])
# tensor([0.1978, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 4, 2, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.1928, 0.1934, 0.2114, 0.2203, 0.1822], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2465, 0.2088, 0.1966, 0.1829], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.2288, 0.1580, 0.0000, 0.2282], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False, False,  True,  True])
# tensor([0.0000, 0.2072, 0.2170, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1847, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 3, 2, 4, 1]
# tensor([False, False, False, False, False])
# tensor([0.1971, 0.2154, 0.1674, 0.2008, 0.2193], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2154, 0.1904, 0.0000, 0.1942, 0.1804], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.2245, 0.0000, 0.1974, 0.2140], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False,  True, False,  True])
# tensor([0.0000, 0.2078, 0.0000, 0.2173, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1616, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.2078, 0.1894, 0.1816, 0.1897, 0.2315], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1822, 0.2075, 0.1960, 0.0000, 0.1909], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True, False])
# tensor([0.2398, 0.0000, 0.2295, 0.0000, 0.1393], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.1794, 0.0000, 0.1807], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1964, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 3, 2, 4, 1]
# tensor([False, False, False, False, False])
# tensor([0.1606, 0.1983, 0.2385, 0.1798, 0.2229], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2051, 0.0000, 0.1833, 0.1672, 0.2165], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.1926, 0.0000, 0.1770, 0.2236, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True,  True])
# tensor([0.1670, 0.0000, 0.2217, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True,  True])
# tensor([0.1728, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 2, 1, 3, 4]
# tensor([False, False, False, False, False])
# tensor([0.2149, 0.2136, 0.1800, 0.1601, 0.2313], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.2127, 0.1861, 0.1891, 0.0000, 0.1934], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True, False])
# tensor([0.1915, 0.0000, 0.2070, 0.0000, 0.1957], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.1925, 0.0000, 0.1841], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.1783, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 1, 4, 3, 2]
# tensor([False, False, False, False, False])
# tensor([0.2169, 0.1687, 0.1866, 0.2039, 0.2239], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1592, 0.1824, 0.2360, 0.1988], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.2157, 0.0000, 0.1610, 0.1921], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.1878, 0.2025], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1986, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 1, 2, 3, 4]
# tensor([False, False, False, False, False])
# tensor([0.1962, 0.1634, 0.2004, 0.2186, 0.2213], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.1778, 0.2407, 0.1791, 0.2076, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False,  True])
# tensor([0.1703, 0.0000, 0.2136, 0.2409, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False,  True])
# tensor([0.1597, 0.0000, 0.0000, 0.2073, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True,  True,  True,  True])
# tensor([0.2216, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 4, 2, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.2245, 0.1800, 0.2353, 0.1584, 0.2018], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.1798, 0.2467, 0.1888, 0.2088, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.1768, 0.1987, 0.2046, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.2143, 0.2244, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2333, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.2478, 0.1719, 0.2099, 0.2024, 0.1680], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.2031, 0.2150, 0.1740, 0.2549, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False,  True])
# tensor([0.1997, 0.2036, 0.0000, 0.1984, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False,  True,  True,  True])
# tensor([0.2052, 0.2246, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1984, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 3, 4, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.2494, 0.2169, 0.2047, 0.1903, 0.1386], grad_fn=<IndexPutBackward0>)
# 0
# ...
# 3
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.2268, 0.1806, 0.0000, 0.1918], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.1684, 0.0000, 0.2157], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2034, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 1, 2, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.1799, 0.2144, 0.1937, 0.2242, 0.1878], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.2341, 0.1841, 0.2138, 0.0000, 0.1988], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.1849, 0.2020, 0.0000, 0.1555], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.1904, 0.0000, 0.1726], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2415], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 2, 4, 1, 3]
# tensor([False, False, False, False, False])
# tensor([0.2270, 0.1623, 0.1773, 0.2381, 0.1953], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1823, 0.2097, 0.1822, 0.0000, 0.2534], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.1949, 0.2480, 0.1891, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False,  True,  True])
# tensor([0.1637, 0.0000, 0.2101, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True,  True,  True])
# tensor([0.2262, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 3, 1, 4, 2]
# tensor([False, False, False, False, False])
# tensor([0.2024, 0.2167, 0.1636, 0.2026, 0.2147], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2019, 0.2052, 0.1953, 0.2195], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True, False])
# tensor([0.0000, 0.2274, 0.1929, 0.0000, 0.1916], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.1744, 0.0000, 0.2008], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2252, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 1, 3, 4, 2]
# tensor([False, False, False, False, False])
# tensor([0.2216, 0.2024, 0.2251, 0.1798, 0.1711], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2008, 0.1737, 0.0000, 0.2114, 0.2086], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.2119, 0.0000, 0.1594, 0.2176], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False,  True, False,  True])
# tensor([0.0000, 0.1958, 0.0000, 0.1977, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1407, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 4, 1, 2, 3]
# tensor([False, False, False, False, False])
# tensor([0.2032, 0.2040, 0.2105, 0.2330, 0.1492], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.2309, 0.2073, 0.1776, 0.0000, 0.1972], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True, False])
# tensor([0.2079, 0.2064, 0.0000, 0.0000, 0.2116], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True,  True,  True])
# tensor([0.2473, 0.2500, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True,  True,  True])
# tensor([0.1676, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 2, 1, 3, 4]
# tensor([False, False, False, False, False])
# tensor([0.2091, 0.2115, 0.1998, 0.2083, 0.1713], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1829, 0.1992, 0.1672, 0.0000, 0.2368], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.2307, 0.2301, 0.1658, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True,  True])
# tensor([0.1814, 0.2034, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1804, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.1935, 0.2074, 0.1847, 0.2301, 0.1843], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2479, 0.1723, 0.2281, 0.1705], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.2127, 0.2151, 0.1709], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.1639, 0.2571], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2487], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 2, 1, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2013, 0.2012, 0.1899, 0.1983, 0.2093], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.2027, 0.2282, 0.0000, 0.1767, 0.1828], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False,  True,  True, False])
# tensor([0.2079, 0.2056, 0.0000, 0.0000, 0.2305], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True,  True, False])
# tensor([0.2356, 0.0000, 0.0000, 0.0000, 0.2127], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2297], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 1, 2, 4, 3]
# tensor([False, False, False, False, False])
# tensor([0.2166, 0.2248, 0.1849, 0.1672, 0.2064], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2515, 0.0000, 0.1753, 0.1817, 0.2037], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False,  True, False,  True, False])
# tensor([0.2263, 0.0000, 0.1809, 0.0000, 0.1671], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False,  True, False])
# tensor([0.0000, 0.0000, 0.2092, 0.0000, 0.2047], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False,  True,  True])
# tensor([0.0000, 0.0000, 0.2203, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.2116, 0.2236, 0.1631, 0.1753, 0.2265], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False, False,  True])
# tensor([0.2153, 0.1687, 0.1466, 0.2238, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.1897, 0.1929, 0.2112, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True, False,  True])
# tensor([0.0000, 0.2332, 0.0000, 0.2140, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1887, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 1, 3, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.1935, 0.1890, 0.2187, 0.2073, 0.1914], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1754, 0.2050, 0.1873, 0.0000, 0.2039], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True, False])
# tensor([0.1948, 0.2136, 0.0000, 0.0000, 0.1881], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True,  True,  True])
# tensor([0.1689, 0.1672, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.1956, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 2, 4, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.2265, 0.1609, 0.2279, 0.1885, 0.1962], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2057, 0.0000, 0.2027, 0.2288, 0.1718], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False, False])
# tensor([0.1751, 0.0000, 0.0000, 0.2208, 0.1915], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True,  True, False,  True])
# tensor([0.1459, 0.0000, 0.0000, 0.1987, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1919, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 4, 1, 2, 3]
# tensor([False, False, False, False, False])
# tensor([0.1865, 0.2766, 0.1621, 0.1782, 0.1966], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1909, 0.2294, 0.2089, 0.0000, 0.1843], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True, False])
# tensor([0.2106, 0.1685, 0.0000, 0.0000, 0.2061], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False,  True,  True,  True])
# tensor([0.1996, 0.2030, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True,  True,  True])
# tensor([0.2177, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 1, 4, 2, 3]
# tensor([False, False, False, False, False])
# tensor([0.1955, 0.1482, 0.1695, 0.1992, 0.2875], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1918, 0.0000, 0.1882, 0.2331, 0.2049], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.1770, 0.1742, 0.2476], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True,  True, False, False,  True])
# tensor([0.0000, 0.0000, 0.2191, 0.2341, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1741, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 3, 2, 1, 4]
# tensor([False, False, False, False, False])
# tensor([0.1986, 0.1975, 0.2172, 0.2023, 0.1845], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.2630, 0.0000, 0.2139, 0.1947, 0.1917], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.1818, 0.1914, 0.2118], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2297, 0.1776], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.1677], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 4, 2, 3, 1]
# tensor([False, False, False, False, False])
# tensor([0.1931, 0.1660, 0.2253, 0.2126, 0.2030], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1892, 0.2130, 0.0000, 0.2144, 0.1972], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True, False, False])
# tensor([0.0000, 0.1952, 0.0000, 0.1728, 0.2423], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False,  True,  True, False])
# tensor([0.0000, 0.2103, 0.0000, 0.0000, 0.1945], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2123], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.2353, 0.1818, 0.1986, 0.1765, 0.2078], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1935, 0.0000, 0.1848, 0.1976, 0.1858], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.2151, 0.0000, 0.1783, 0.2240, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False,  True])
# tensor([0.1986, 0.0000, 0.0000, 0.2125, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.1824, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# [0, 1, 2, 3, 4]
# tensor([False, False, False, False, False])
# tensor([0.1632, 0.2515, 0.2213, 0.1938, 0.1702], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1619, 0.1907, 0.0000, 0.1971, 0.2489], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True, False, False])
# tensor([0.2159, 0.0000, 0.0000, 0.1471, 0.1997], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2165, 0.1922], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2025], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 4, 3, 1, 2]
# tensor([False, False, False, False, False])
# tensor([0.2028, 0.1834, 0.2170, 0.2229, 0.1739], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.1911, 0.1858, 0.2101, 0.1887], grad_fn=<IndexPutBackward0>)
# 4
# tensor([ True, False, False, False,  True])
# tensor([0.0000, 0.1932, 0.2231, 0.1775, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True, False, False,  True,  True])
# tensor([0.0000, 0.1802, 0.2099, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True, False,  True,  True,  True])
# tensor([0.0000, 0.2017, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# finished!
# [0, 4, 1, 2, 3]
# tensor([False, False, False, False, False])
# tensor([0.2316, 0.1820, 0.1963, 0.2042, 0.1858], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.1726, 0.1866, 0.2479, 0.0000, 0.1862], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False, False, False,  True,  True])
# tensor([0.2254, 0.1936, 0.2243, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True,  True])
# tensor([0.1632, 0.1884, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True,  True,  True])
# tensor([0.2433, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.1810, 0.2203, 0.1643, 0.2505, 0.1838], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True, False, False])
# tensor([0.1773, 0.1897, 0.0000, 0.1652, 0.2587], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False,  True,  True, False])
# tensor([0.2235, 0.1941, 0.0000, 0.0000, 0.1695], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True,  True,  True, False])
# tensor([0.1565, 0.0000, 0.0000, 0.0000, 0.2667], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True,  True,  True,  True])
# tensor([0.1831, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# finished!
# [0, 4, 1, 2, 3]
# tensor([False, False, False, False, False])
# tensor([0.2280, 0.2425, 0.1779, 0.2041, 0.1475], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False, False, False, False])
# tensor([0.0000, 0.2134, 0.1785, 0.1829, 0.2085], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True, False, False, False])
# tensor([0.0000, 0.0000, 0.2041, 0.2272, 0.1875], grad_fn=<IndexPutBackward0>)
# 2
# tensor([ True,  True,  True, False, False])
# tensor([0.0000, 0.0000, 0.0000, 0.2138, 0.1797], grad_fn=<IndexPutBackward0>)
# 3
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2351], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 1, 3, 4, 2]
# tensor([False, False, False, False, False])
# tensor([0.1918, 0.2083, 0.2026, 0.2216, 0.1756], grad_fn=<IndexPutBackward0>)
# 3
# tensor([False, False, False,  True, False])
# tensor([0.2172, 0.1791, 0.1836, 0.0000, 0.1895], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False, False,  True,  True, False])
# tensor([0.1971, 0.1765, 0.0000, 0.0000, 0.2141], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True, False,  True,  True, False])
# tensor([0.0000, 0.1935, 0.0000, 0.0000, 0.1941], grad_fn=<IndexPutBackward0>)
# 1
# tensor([ True,  True,  True,  True, False])
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.2220], grad_fn=<IndexPutBackward0>)
# 4
# finished!
# [0, 3, 1, 2, 4]
# tensor([False, False, False, False, False])
# tensor([0.2005, 0.1676, 0.2365, 0.1921, 0.2033], grad_fn=<IndexPutBackward0>)
# 1
# tensor([False,  True, False, False, False])
# tensor([0.1484, 0.0000, 0.2235, 0.1991, 0.1842], grad_fn=<IndexPutBackward0>)
# 4
# tensor([False,  True, False, False,  True])
# tensor([0.2090, 0.0000, 0.2083, 0.1796, 0.0000], grad_fn=<IndexPutBackward0>)
# 2
# tensor([False,  True,  True, False,  True])
# tensor([0.2306, 0.0000, 0.0000, 0.1985, 0.0000], grad_fn=<IndexPutBackward0>)
# 0
# tensor([ True,  True,  True, False,  True])
# tensor([0.0000, 0.0000, 0.0000, 0.2508, 0.0000], grad_fn=<IndexPutBackward0>)
# 3
# finished!
# Episode 100/100, Total Reward: -2.613534067600749, Episode Loss: 8.12190067768097

# %%
# other loss function:
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np

def compute_tour_length(adj_matrix, tour):
    tour_length = 0
    for i in range(len(tour) - 1):
        tour_length += adj_matrix[tour[i], tour[i + 1]]
    tour_length += adj_matrix[tour[-1], tour[0]]  # Return to the starting point
    return tour_length

def train_online(model, env, num_episodes=100):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for episode in range(num_episodes):
        state, _ = env.reset()
        done = False
        total_loss = 0
        total_reward = 0
        counter = 0

        selected_actions = []
        log_probs = []

        while not done:
            curr_node = state["current_node"]
            visited = state["visited"]
            adj_matrix = state["adjacency_matrix"]
            num_nodes = adj_matrix.shape[0]

            # obs for each node
            node_observations = []
            for i in range(num_nodes):
                distance_to_current_node = adj_matrix[curr_node, i]
                visited_status = float(visited[i])
                node_observations.append([distance_to_current_node, visited_status])
            node_observations = torch.tensor(node_observations).float().unsqueeze(0)  # [1, num_nodes, 2]

            # action for each node
            actions = []
            for i in range(num_nodes):
                next_node_index = i
                travel_cost = adj_matrix[curr_node, next_node_index]
                actions.append([next_node_index, travel_cost])
            actions = torch.tensor(actions).float().unsqueeze(0) # [1, num_nodes, 2]

            return_to_go = torch.tensor(np.random.rand(1, num_nodes, 1), dtype=torch.float)

            # action probabilities
            action_probs = model(node_observations, actions, return_to_go)  # [1, num_nodes, 128]
            action_probs_no_batch = action_probs.squeeze(0) # [num_nodes, 128]
            score_layer = nn.Linear(128, 1)

            # convert features to scores
            scores = score_layer(action_probs_no_batch)
            probabilities = F.softmax(scores.squeeze(1), dim=-1)

            distribution = torch.distributions.Categorical(probs=probabilities)

            # sample an action
            selected_action = distribution.sample().item()
            log_prob = distribution.log_prob(torch.tensor(selected_action))
            log_probs.append(log_prob)

            selected_actions.append(selected_action)

            # next state
            next_state, reward, done, _ = env.step(selected_action)
            total_reward += reward
            state = next_state
            counter += 1

        # Compute tour lengths
        model_tour_length = compute_tour_length(state["adjacency_matrix"], selected_actions)
        optimal_path = env.optimal_solution()
        optimal_tour_length = compute_tour_length(state["adjacency_matrix"], optimal_path)

        # Compute loss
        tour_length_diff = model_tour_length - optimal_tour_length
        log_probs_sum = torch.stack(log_probs).sum()
        loss = tour_length_diff * log_probs_sum
        print(loss)

        total_loss += loss.item()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}, Episode Loss: {total_loss}")

if __name__ == "__main__":
    env = ATSPEnv(num_nodes=5, seed=42)

    state_dim = 2
    action_dim = 2

    config = DecisionTransformer.DTConfig(n_embd=128)
    model = DecisionTransformer(state_dim=state_dim, action_dim=action_dim, config=config)

    train_online(model, env)
    torch.save(model.state_dict(), "decision_transformer_model.pth")

# %% [markdown]
# Eval
